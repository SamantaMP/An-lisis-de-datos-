# %%
#Cargar Librerias que necesitamos
import pandas as pd #estrucutra de datos 
import numpy as np #calculo metrico y analisis de datos
import seaborn as sns #viasulizar datos estadisticos
import matplotlib.pyplot as plt #graficas


from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.metrics import confusion_matrix



#libreria de ciencia de datos
from sklearn.linear_model import Ridge
from sklearn import metrics  #metricas evaluativas
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# 𝐑𝐞𝐠𝐫𝐞𝐬𝐢𝐨́𝐧 Lineal

# %% [markdown]
# 𝟏. 𝐑𝐞𝐚𝐥𝐢𝐳𝐚𝐫 𝐮𝐧 𝐚𝐧𝐚́𝐥𝐢𝐬𝐢𝐬 𝐞𝐱𝐩𝐥𝐨𝐫𝐚𝐭𝐨𝐫𝐢𝐨 𝐝𝐞 𝐥𝐨𝐬 𝐝𝐚𝐭𝐨𝐬 𝐩𝐚𝐫𝐚 𝐢𝐝𝐞𝐧𝐭𝐢𝐟𝐢𝐜𝐚𝐫
# 𝐫𝐞𝐥𝐚𝐜𝐢𝐨𝐧𝐞𝐬 𝐞𝐧𝐭𝐫𝐞 𝐯𝐚𝐫𝐢𝐚𝐛𝐥𝐞𝐬, 𝐯𝐚𝐥𝐨𝐫𝐞𝐬 𝐚𝐭𝐢́𝐩𝐢𝐜𝐨𝐬, 𝐭𝐞𝐧𝐝𝐞𝐧𝐜𝐢𝐚𝐬, 𝐞𝐭𝐜.

# %%
datos = pd.read_csv('C:/Users/saman/Downloads/tareafinal/Titanic.csv', encoding='ISO-8859-1')

# %%
datos.head(15) #visualizacion y descripcion  de los datos
# Out:
#    Id_pasajero  Sobrevivio  ClaseP  \
# 0            1         0.0     3.0
# 1            2         1.0     1.0
# 2            3         1.0     3.0
# 3            4         1.0     1.0
# 4            5         0.0     3.0
# 5            6         0.0     3.0
# 6            7         0.0     1.0
# 7            8         0.0     3.0
# 8            9         1.0     3.0
# 9           10         1.0     2.0
# 10          11         1.0     3.0
# 11          12         1.0     1.0
# 12          13         0.0     3.0
# 13          14         0.0     3.0
# 14          15         0.0     3.0
#
#                                                Nombre    Sexo  Edad  \
# 0                            Braund   Mr. Owen Harris    male  22.0
# 1   Cumings   Mrs. John Bradley (Florence Briggs T...  female  38.0
# 2                             Heikkinen   Miss. Laina  female  26.0
# 3       Futrelle   Mrs. Jacques Heath (Lily May Peel)  female  35.0
# ...

# %%
datos.info() #informacion de datos y tipo
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id_pasajero     891 non-null    object
#  1   Sobrevivio      838 non-null    float64
#  2   ClaseP          838 non-null    float64
#  3   Nombre          838 non-null    object
#  4   Sexo            838 non-null    object
#  5   Edad            679 non-null    float64
#  6   Familar_abordo  838 non-null    float64
#  7   Parch           838 non-null    float64
#  8   Ticket          838 non-null    object
#  9   tarifa          838 non-null    float64
#  10  Cabina          196 non-null    object
#  11  Embarcado       836 non-null    object
# dtypes: float64(6), object(6)
# memory usage: 83.7+ KB

# %%
datos.Sobrevivio = datos.Sobrevivio.fillna(0) #convertir valores nulos a 0
datos.Sobrevivio = datos.Sobrevivio.astype(int) #CONVERTIR FLOAT A ENTEROS

datos.ClaseP = datos.ClaseP.fillna(0) #convertir valores nulos a 0
datos.ClaseP = datos.ClaseP.astype(int) 

datos.Edad = datos.Edad.fillna(0) #convertir valores nulos a 0
datos.Edad = datos.Edad.astype(int) 

datos.Familar_abordo = datos.Familar_abordo.fillna(0) #convertir valores nulos a 0
datos.Familar_abordo = datos.Familar_abordo.astype(int) 

datos.Parch = datos.Parch.fillna(0) #convertir valores nulos a 0
datos.Parch = datos.Parch.astype(int)

# %%
plt.figure(figsize=(6, 3))
sns.boxplot(x=datos['Edad'], color='#D7F205')  # Aquí usamos el código hexadecimal dentro de comillas para cambair el color
plt.title('Identificación de datos faltantes y atípicos', fontsize=10)
plt.show()

# %% [markdown]
# Se debe corregir los valores en 0

# %%
plt.figure(figsize=(6, 3))
sns.boxplot(x=datos['Sobrevivio'], color='#D7F205')  # Aquí usamos el código hexadecimal dentro de comillas para cambair el color
plt.title('Identificación de datos faltantes y atípicos', fontsize=10)
plt.show()

# %% [markdown]
# 𝐍𝐨 𝐬𝐞 𝐞𝐯𝐢𝐝𝐞𝐧𝐜𝐢𝐚 𝐝𝐚𝐭𝐨𝐬 𝐚𝐭𝐢́𝐩𝐢𝐜𝐨𝐬 𝐞𝐧 𝐥𝐚 𝐯𝐚𝐫𝐢𝐚𝐛𝐥𝐞.

# %%
datos.describe() #trae diversas medidas estadisticas
# Out:
#        Sobrevivio      ClaseP        Edad  Familar_abordo       Parch  \
# count  891.000000  891.000000  891.000000      891.000000  891.000000
# mean     0.341190    2.164983   22.854097        0.497194    0.356902
# std      0.474375    0.979995   18.014883        1.070935    0.789328
# min      0.000000    0.000000    0.000000        0.000000    0.000000
# 25%      0.000000    1.000000    1.000000        0.000000    0.000000
# 50%      0.000000    3.000000   24.000000        0.000000    0.000000
# 75%      1.000000    3.000000   35.000000        1.000000    0.000000
# max      1.000000    3.000000   80.000000        8.000000    6.000000
#
#              tarifa
# count  8.380000e+02
# mean   1.320711e+05
# std    4.226605e+05
# min    0.000000e+00
# 25%    1.450000e+01
# 50%    7.705000e+01
# 75%    7.895800e+04
# max    5.123292e+06

# %% [markdown]
# 𝐄𝐧 𝐥𝐚 𝐞𝐝𝐚𝐝 : Media (mean = 22): El valor promedio de los datos es 22.
# Desviación estándar (std = 13): Los valores individuales en el conjunto de datos tienden a desviarse en promedio 13 unidades de la media de 22.

# %% [markdown]
# El promedio de 𝐬𝐨𝐛𝐫𝐞𝐯𝐢𝐯𝐢𝐞𝐧𝐭𝐞𝐬  0.341190

# %%
# Calcular la media de 'resultado' por 'edad' y ordenar
media_sobrevivio_por_edad = datos.groupby('Edad')['Sobrevivio'].mean().sort_values(ascending=False)
# Seleccionar las 5 edades con mayor media de 'Sobrevivio'
top_5_edad = media_sobrevivio_por_edad.head(5).index
# Filtrar el DataFrame para incluir solo las edades seleccionadas
datos_top_5 = datos[datos['Edad'].isin(top_5_edad)]
# Ajusta el tamaño de la figura
plt.figure(figsize=(17, 6))

# Crear un gráfico de barras agrupadas y ordenadas
sns.barplot(data=datos_top_5, x='Edad', y='Sobrevivio', order=top_5_edad)
plt.title('Resultados por Edad y sobrevivivientes ')
plt.xlabel('Edad')
plt.ylabel('Sobrevivio')
plt.show()

# %% [markdown]
# 𝐋𝐚𝐬 𝐭𝐫𝐞𝐬 𝐞𝐝𝐚𝐝𝐞𝐬 𝐜𝐨𝐧 𝐦𝐚𝐲𝐨𝐫𝐞𝐬 𝐩𝐞𝐫𝐝𝐢𝐝𝐚𝐬 𝐟𝐮𝐞𝐫𝐨𝐧 𝟖𝟎, 𝟏𝟑, 𝟔𝟑, 𝟓 𝐲 𝟓𝟑

# %%
# Contar las ocurrencias de cada 'Edad'
conteo_edades = datos['Edad'].value_counts()

# Seleccionar las 6 edades con más frecuencia
top_6_edades = conteo_edades.head(6).index

# Filtrar el DataFrame para incluir solo las edades seleccionadas
datos_top_6 = datos[datos['Edad'].isin(top_6_edades)]

# Contar las ocurrencias de cada 'Edad' nuevamente para los datos filtrados
conteo_edades_top_6 = datos_top_6['Edad'].value_counts()

# Crear las etiquetas para el gráfico de pastel
etiquetas = [f'Edad {edad}' for edad in conteo_edades_top_6.index]

# Crear el gráfico de pastel
plt.figure(figsize=(10, 7))
plt.pie(conteo_edades_top_6, labels=etiquetas, autopct='%.2f%%', startangle=140)
plt.title('Distribución de las 6 Edades con Más Resultados')
plt.show()

# %% [markdown]
# 𝟐. 𝐏𝐫𝐞𝐩𝐫𝐨𝐜𝐞𝐬𝐚𝐫 𝐥𝐨𝐬 𝐝𝐚𝐭𝐨𝐬 𝐥𝐢𝐦𝐩𝐢𝐚́𝐧𝐝𝐨𝐥𝐨𝐬, 𝐭𝐫𝐚𝐭𝐚𝐧𝐝𝐨 𝐯𝐚𝐥𝐨𝐫𝐞𝐬 𝐟𝐚𝐥𝐭𝐚𝐧𝐭𝐞𝐬 𝐲
# 𝐭𝐫𝐚𝐧𝐬𝐟𝐨𝐫𝐦𝐚́𝐧𝐝𝐨𝐥𝐨𝐬 𝐬𝐞𝐠𝐮́𝐧 𝐬𝐞𝐚 𝐧𝐞𝐜𝐞𝐬𝐚𝐫𝐢𝐨.

# %%
datos.isna().sum()  #confirmacion de datos nulos, de forma simple
# Out:
# Id_pasajero         0
# Sobrevivio          0
# ClaseP              0
# Nombre             53
# Sexo               53
# Edad                0
# Familar_abordo      0
# Parch               0
# Ticket             53
# tarifa             53
# Cabina            695
# Embarcado          55
# dtype: int64

# %%
nivel_minimo = 1
nivel_maximo = 80

total_atipico = ((datos['Edad'] < nivel_minimo) | (datos['Edad'] > nivel_maximo)).sum()
print("El total de datos atípicos es: {}".format(total_atipico))
#filtro o elimiancion de datos atipicos
datos = datos[(datos['Edad'] >= nivel_minimo) & (datos['Edad'] <= nivel_maximo)]
# Out:
# El total de datos atípicos es: 219

# %%
# Contar las ocurrencias de cada 'Edad'
conteo_edades = datos['Edad'].value_counts()

# Seleccionar las 6 edades con más frecuencia
top_6_edades = conteo_edades.head(6).index

# Filtrar el DataFrame para incluir solo las edades seleccionadas
datos_top_6 = datos[datos['Edad'].isin(top_6_edades)]

# Contar las ocurrencias de cada 'Edad' nuevamente para los datos filtrados
conteo_edades_top_6 = datos_top_6['Edad'].value_counts()

# Crear las etiquetas para el gráfico de pastel
etiquetas = [f'Edad {edad}' for edad in conteo_edades_top_6.index]

# Crear el gráfico de pastel
plt.figure(figsize=(10, 7))
plt.pie(conteo_edades_top_6, labels=etiquetas, autopct='%.2f%%', startangle=140)
plt.title('Distribución de las 6 Edades con Más Resultados')
plt.show()

# %% [markdown]
# 𝐒𝐞 𝐨𝐛𝐭𝐢𝐞𝐧𝐞 𝐠𝐫𝐚𝐟𝐢𝐜𝐚 𝐬𝐢𝐧 𝐯𝐚𝐥𝐨𝐫𝐞𝐬  𝐞𝐧 𝐞𝐝𝐚𝐝 𝐚𝐭𝐢́𝐩𝐢𝐜𝐨𝐬, 𝐦𝐨𝐬𝐭𝐫𝐚𝐦𝐨𝐬 𝐪𝐮𝐞 𝐥𝐚 𝐞𝐝𝐚𝐝 𝐝𝐞 𝟐𝟒 𝐟𝐮𝐞 𝐮𝐧𝐚 𝐝𝐞 𝐥𝐚𝐬 𝐞𝐝𝐚𝐝𝐞𝐬 𝐜𝐨𝐧 𝐦𝐚𝐲𝐨𝐫𝐞𝐬 𝐩𝐞𝐫𝐝𝐢𝐝𝐚𝐬

# %%
nivel_minimo = 0
nivel_maximo = 1

total_atipico = ((datos['Sobrevivio'] < nivel_minimo) | (datos['Sobrevivio'] > nivel_maximo)).sum()
print("El total de datos atípicos es: {}".format(total_atipico))
# Out:
# El total de datos atípicos es: 0

# %%
# Agrupar los datos por sexo y contar la cantidad de sobrevivientes
conteo_sobrevivientes_sexo = datos[datos['Sobrevivio'] == 1]['Sexo'].value_counts()

# Crear las etiquetas para el gráfico de pastel
etiquetas = [f'Sexo {sexo}' for sexo in conteo_sobrevivientes_sexo.index]

colores = ['#E076D3','#8DE0CF']

plt.figure(figsize=(10, 7))
plt.pie(conteo_sobrevivientes_sexo, labels=etiquetas, autopct='%.2f%%', startangle=140, colors=colores, wedgeprops={'edgecolor': 'black'})
plt.title('Proporción de Sobrevivientes por Sexo')
plt.show()

# %% [markdown]
# 𝟯. 𝙎𝙚𝙡𝙚𝙘𝙘𝙞𝙤𝙣𝙖𝙧 𝙡𝙖𝙨 𝙘𝙖𝙧𝙖𝙘𝙩𝙚𝙧𝙞́𝙨𝙩𝙞𝙘𝙖𝙨 𝙢𝙖́𝙨 𝙧𝙚𝙡𝙚𝙫𝙖𝙣𝙩𝙚𝙨 𝙥𝙖𝙧𝙖 𝙚𝙣𝙩𝙧𝙚𝙣𝙖𝙧 𝙚𝙡
# 𝙢𝙤𝙙𝙚𝙡𝙤 𝙪𝙩𝙞𝙡𝙞𝙯𝙖𝙣𝙙𝙤 𝙨𝙚𝙡𝙚𝙘𝙘𝙞𝙤́𝙣 𝙙𝙚 𝙘𝙖𝙧𝙖𝙘𝙩𝙚𝙧𝙞́𝙨𝙩𝙞𝙘𝙖𝙨.

# %% [markdown]
# Las características que se deben tener más en cuenta son Edad y sobreviviente, también puede tomare género.

# %%
#Filtrar las columnas de datoos 
datos = datos[["Edad", "Sexo", "Sobrevivio"]]
datos.head(5) #Revision de las variables
# Out:
#    Edad    Sexo  Sobrevivio
# 0    22    male           0
# 1    38  female           1
# 2    26  female           1
# 3    35  female           1
# 4    35    male           0

# %% [markdown]
# 𝟒. 𝐃𝐢𝐯𝐢𝐝𝐢𝐫 𝐞𝐥 𝐝𝐚𝐭𝐚𝐬𝐞𝐭 𝐞𝐧 𝐓𝐫𝐚𝐢𝐧 𝐲 𝐓𝐞𝐬𝐭 𝐩𝐚𝐫𝐚 𝐞𝐯𝐚𝐥𝐮𝐚𝐫 𝐜𝐨𝐫𝐫𝐞𝐜𝐭𝐚𝐦𝐞𝐧𝐭𝐞 𝐞𝐥
# 𝐦𝐨𝐝𝐞𝐥𝐨
#
# 𝟓. 𝐄𝐧𝐭𝐫𝐞𝐧𝐚𝐫 𝐞𝐥 𝐦𝐨𝐝𝐞𝐥𝐨 𝐜𝐨𝐧𝐟𝐢𝐠𝐮𝐫𝐚𝐧𝐝𝐨 𝐥𝐨𝐬 𝐝𝐢𝐟𝐞𝐫𝐞𝐧𝐭𝐞𝐬
# 𝐡𝐢𝐩𝐞𝐫𝐩𝐚𝐫𝐚́𝐦𝐞𝐭𝐫𝐨𝐬.

# %%
# Dividir los datos en características (X) y la variable objetivo (y)
X = datos.drop('Sobrevivio', axis=1)  # Características
y = datos['Sobrevivio']  # Variable objetivo

# Dividir los datos en conjuntos de entrenamiento y prueba (80% para entrenamiento, 20% para prueba)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Definir las columnas categóricas y numéricas
columnas_categoricas = ['Sexo']  # Especifica las columnas categóricas
columnas_numericas = [col for col in X.columns if col not in columnas_categoricas]

# Definir el transformador para aplicar One-Hot Encoding a las variables categóricas
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(), columnas_categoricas),  # Aplica One-Hot Encoding a las columnas categóricas, El nombre "onehot" es un identificador para este transformador
        ('passthrough', 'passthrough', columnas_numericas)  # Deja las columnas numéricas sin modificar 'passthrough' indica que las columnas deben dejarse sin modificar
    ])

# Aplicar el preprocesamiento a los datos de entrenamiento y prueba
X_train_processed = preprocessor.fit_transform(X_train)
X_test_processed = preprocessor.transform(X_test)

# Inicializar y entrenar el modelo de regresión lineal
modelo_regresion = LinearRegression()
modelo_regresion.fit(X_train_processed, y_train)

print(X_test)
# Out:
#      Edad    Sexo
# 780    13  female
# 407     3    male
# 15     55  female
# 855    18  female
# 100    28  female
# ..    ...     ...
# 890    32    male
# 249    54    male
# 655    24    male
# 131    20    male
# 321    27    male
#
# [135 rows x 2 columns]

# %%
print(X_train)
# Out:
#      Edad    Sexo
# 695    52    male
# 417    18  female
# 188    40    male
# 310    24  female
# 704    26    male
# ..    ...     ...
# 10      4  female
# 478    22    male
# 255    29  female
# 840    20    male
# 750     4  female
#
# [537 rows x 2 columns]

# %% [markdown]
# 𝟔. 𝐄𝐯𝐚𝐥𝐮𝐚𝐫 𝐞𝐥 𝐝𝐞𝐬𝐞𝐦𝐩𝐞𝐧̃𝐨 𝐝𝐞𝐥 𝐦𝐨𝐝𝐞𝐥𝐨 𝐞𝐧 𝐞𝐥 𝐜𝐨𝐧𝐣𝐮𝐧𝐭𝐨 𝐝𝐞 𝐓𝐞𝐬𝐭 𝐜𝐨𝐧
# 𝐦𝐞́𝐭𝐫𝐢𝐜𝐚𝐬 𝐜𝐨𝐦𝐨 𝐩𝐫𝐞𝐜𝐢𝐬𝐢𝐨́𝐧, 𝐫𝐞𝐜𝐚𝐥𝐥, 𝐅𝟏-𝐬𝐜𝐨𝐫𝐞, 𝐞𝐭𝐜.
# .

# %%
# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_test, y_pred_binario)

# Extraer los valores de la matriz de confusión
TN, FP, FN, TP = conf_matrix.ravel()

print(f'Verdaderos Negativos (TN): {TN}')
print(f'Falsos Positivos (FP): {FP}')
print(f'Falsos Negativos (FN): {FN}')
print(f'Verdaderos Positivos (TP): {TP}')

# Calcular métricas adicionales
sensibilidad = TP / (TP + FN)  # También conocido como Recall
especificidad = TN / (TN + FP)
precision = TP / (TP + FP)
exactitud = (TP + TN) / (TP + TN + FP + FN)
f1_score = 2 * (precision * sensibilidad) / (precision + sensibilidad)

print(f'Sensibilidad (Recall): {sensibilidad}')
print(f'Especificidad: {especificidad}')
print(f'Precision: {precision}')
print(f'Exactitud: {exactitud}')
print(f'F1-score: {f1_score}')
# Out:
# Verdaderos Negativos (TN): 65
# Falsos Positivos (FP): 10
# Falsos Negativos (FN): 15
# Verdaderos Positivos (TP): 45
# Sensibilidad (Recall): 0.75
# Especificidad: 0.8666666666666667
# Precision: 0.8181818181818182
# Exactitud: 0.8148148148148148
# F1-score: 0.7826086956521738

# %% [markdown]
# 𝟕. 𝐑𝐞𝐚𝐥𝐢𝐳𝐚𝐫 𝐥𝐚𝐬 𝐝𝐢𝐟𝐞𝐫𝐞𝐧𝐭𝐞𝐬 𝐠𝐫𝐚́𝐟𝐢𝐜𝐚𝐬 𝐪𝐮𝐞 𝐩𝐞𝐫𝐦𝐢𝐭𝐚𝐧 𝐯𝐢𝐬𝐮𝐚𝐥𝐢𝐳𝐚𝐫 𝐥𝐨𝐬
# 𝐫𝐞𝐬𝐮𝐥𝐭𝐚𝐝𝐨𝐬 𝐝𝐞𝐥 𝐦𝐨𝐝𝐞𝐥𝐨.

# %%
# Definir las métricas y sus valores
metricas = ['Precision', 'Recall', 'Exactitud', 'F1-score']
valores = [precision, sensibilidad, exactitud, f1_score]

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(metricas, valores, color='skyblue')
plt.title('Métricas de Evaluación')
plt.xlabel('Métricas')
plt.ylabel('Valor')
plt.ylim(0, 1)  # Establecer el límite y para el eje y entre 0 y 1
plt.show()

# %%
# Definir los valores para el gráfico de pastel
valores_pastel = [sensibilidad, especificidad]
etiquetas_pastel = ['Sensibilidad (Recall)', 'Especificidad']

# Crear el gráfico de pastel
plt.figure(figsize=(8, 6))
plt.pie(valores_pastel, labels=etiquetas_pastel, autopct='%.2f%%', colors=['lightgreen', 'lightblue'])
plt.title('Sensibilidad (Recall) vs. Especificidad')
plt.show()

# %% [markdown]
# 𝟖. 𝐈𝐧𝐭𝐞𝐫𝐩𝐫𝐞𝐭𝐚𝐫, 𝐚𝐧𝐚𝐥𝐢𝐳𝐚𝐫 𝐲 𝐝𝐨𝐜𝐮𝐦𝐞𝐧𝐭𝐚𝐫 𝐥𝐨𝐬 𝐫𝐞𝐬𝐮𝐥𝐭𝐚𝐝𝐨𝐬 𝐨𝐛𝐭𝐞𝐧𝐢𝐝𝐨𝐬

# %% [markdown]
# 𝙀𝙭𝙖𝙘𝙩𝙞𝙩𝙪𝙙 𝙙𝙚 𝟬.𝟳𝟵𝟴𝟵 𝙨𝙞𝙜𝙣𝙞𝙛𝙞𝙘𝙖 𝙦𝙪𝙚 𝙚𝙡 𝙢𝙤𝙙𝙚𝙡𝙤 𝙝𝙖 𝙧𝙚𝙖𝙡𝙞𝙯𝙖𝙙𝙤 𝙘𝙤𝙧𝙧𝙚𝙘𝙩𝙖𝙢𝙚𝙣𝙩𝙚 𝙡𝙖 𝙘𝙡𝙖𝙨𝙞𝙛𝙞𝙘𝙖𝙘𝙞𝙤́𝙣 𝙚𝙣 𝙖𝙥𝙧𝙤𝙭𝙞𝙢𝙖𝙙𝙖𝙢𝙚𝙣𝙩𝙚 𝙚𝙡 𝟳𝟵.𝟴𝟵% 𝙙𝙚 𝙡𝙤𝙨 𝙘𝙖𝙨𝙤𝙨 𝙚𝙣 𝙚𝙡 𝙘𝙤𝙣𝙟𝙪𝙣𝙩𝙤 𝙙𝙚 𝙙𝙖𝙩𝙤𝙨 𝙙𝙚 𝙥𝙧𝙪𝙚𝙗𝙖. 𝙀𝙣 𝙩𝙚́𝙧𝙢𝙞𝙣𝙤𝙨 𝙜𝙚𝙣𝙚𝙧𝙖𝙡𝙚𝙨, 𝙪𝙣 𝙫𝙖𝙡𝙤𝙧 𝙙𝙚 𝙚𝙭𝙖𝙘𝙩𝙞𝙩𝙪𝙙 𝙢𝙖́𝙨 𝙘𝙚𝙧𝙘𝙖𝙣𝙤 𝙖 𝟭 𝙞𝙣𝙙𝙞𝙘𝙖 𝙪𝙣 𝙢𝙚𝙟𝙤𝙧 𝙧𝙚𝙣𝙙𝙞𝙢𝙞𝙚𝙣𝙩𝙤 𝙙𝙚𝙡 𝙢𝙤𝙙𝙚𝙡𝙤
#
#  𝙇𝙤𝙨 𝙘𝙖𝙨𝙤𝙨 𝙦𝙪𝙚 𝙨𝙤𝙣 𝙥𝙤𝙨𝙞𝙩𝙞𝙫𝙤𝙨 𝙚𝙣 𝙧𝙚𝙖𝙡𝙞𝙙𝙖𝙙, 𝙚𝙡 𝙢𝙤𝙙𝙚𝙡𝙤 𝙝𝙖 𝙡𝙤𝙜𝙧𝙖𝙙𝙤 𝙘𝙖𝙥𝙩𝙪𝙧𝙖𝙧 𝙚𝙡 𝟳𝟮.𝟬𝟲% 𝙙𝙚 𝙚𝙡𝙡𝙤𝙨.
#
# 𝙁𝟭-𝙨𝙘𝙤𝙧𝙚 𝙙𝙚 𝟬.𝟳𝟯𝟭𝟯 𝙞𝙣𝙙𝙞𝙘𝙖 𝙪𝙣 𝙗𝙪𝙚𝙣 𝙚𝙦𝙪𝙞𝙡𝙞𝙗𝙧𝙞𝙤 𝙚𝙣𝙩𝙧𝙚 𝙡𝙖 𝙥𝙧𝙚𝙘𝙞𝙨𝙞𝙤́𝙣 𝙮 𝙚𝙡 𝙧𝙚𝙘𝙖𝙡𝙡 𝙙𝙚𝙡 𝙢𝙤𝙙𝙚𝙡𝙤. 𝙀𝙨𝙩𝙚 𝙫𝙖𝙡𝙤𝙧 𝙨𝙪𝙜𝙞𝙚𝙧𝙚 𝙦𝙪𝙚 𝙚𝙡 𝙢𝙤𝙙𝙚𝙡𝙤 𝙩𝙞𝙚𝙣𝙚 𝙪𝙣 𝙗𝙪𝙚𝙣 𝙧𝙚𝙣𝙙𝙞𝙢𝙞𝙚𝙣𝙩𝙤 𝙚𝙣 𝙩𝙚́𝙧𝙢𝙞𝙣𝙤𝙨 𝙙𝙚 𝙘𝙡𝙖𝙨𝙞𝙛𝙞𝙘𝙖𝙧 𝙘𝙤𝙧𝙧𝙚𝙘𝙩𝙖𝙢𝙚𝙣𝙩𝙚 𝙡𝙖𝙨 𝙞𝙣𝙨𝙩𝙖𝙣𝙘𝙞𝙖𝙨 𝙥𝙤𝙨𝙞𝙩𝙞𝙫𝙖𝙨 (𝙖𝙡𝙩𝙖 𝙥𝙧𝙚𝙘𝙞𝙨𝙞𝙤́𝙣) 𝙮 𝙧𝙚𝙘𝙪𝙥𝙚𝙧𝙖𝙧 𝙡𝙖 𝙢𝙖𝙮𝙤𝙧𝙞́𝙖 𝙙𝙚 𝙡𝙖𝙨 𝙞𝙣𝙨𝙩𝙖𝙣𝙘𝙞𝙖𝙨 𝙥𝙤𝙨𝙞𝙩𝙞𝙫𝙖𝙨 𝙚𝙣 𝙚𝙡 𝙘𝙤𝙣𝙟𝙪𝙣𝙩𝙤 𝙙𝙚 𝙙𝙖𝙩𝙤𝙨 (𝙖𝙡𝙩𝙤 𝙧𝙚𝙘𝙖𝙡𝙡).
#
# 𝙎𝙤𝙗𝙧𝙚𝙫𝙞𝙫𝙞𝙚𝙧𝙤𝙣 𝙢𝙖𝙨 𝙢𝙪𝙟𝙚𝙧𝙚𝙨.
#
# 𝐒𝐞 𝐨𝐛𝐭𝐢𝐞𝐧𝐞 𝐠𝐫𝐚𝐟𝐢𝐜𝐚 𝐬𝐢𝐧 𝐯𝐚𝐥𝐨𝐫𝐞𝐬  𝐞𝐧 𝐞𝐝𝐚𝐝 𝐚𝐭𝐢́𝐩𝐢𝐜𝐨𝐬, 𝐦𝐨𝐬𝐭𝐫𝐚𝐦𝐨𝐬 𝐪𝐮𝐞 𝐥𝐚 𝐞𝐝𝐚𝐝 𝐝𝐞 𝟐𝟒 𝐟𝐮𝐞 𝐮𝐧𝐚 𝐝𝐞 𝐥𝐚𝐬 𝐞𝐝𝐚𝐝𝐞𝐬 𝐜𝐨𝐧 𝐦𝐚𝐲𝐨𝐫𝐞𝐬 𝐩𝐞𝐫𝐝𝐢𝐝𝐚𝐬
